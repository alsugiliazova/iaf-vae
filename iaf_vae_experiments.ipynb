# %%
# !git clone https://github.com/alsugiliazova/iaf-vae.git
# Out:
# Cloning into 'iaf-vae'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 121 (delta 6), reused 11 (delta 3), pack-reused 105 (from 1)
# Receiving objects: 100% (121/121), 1.14 MiB | 24.77 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# %ls
# %cd iaf-vae
# !git pull
# !git checkout clean_original
# Out:
# iaf-vae/  sample_data/
# /content/iaf-vae
# Already up to date.
# Branch 'clean_original' set up to track remote branch 'clean_original' from 'origin'.
# Switched to a new branch 'clean_original'

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !python3 main.py --batch_size 256 --depth 1 --n_blocks 20 --free_bits 0.1 --lr 0.002 --z_size 32 --h_size 160 --iaf 1 --n_epochs 150
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# VAE(
#   (layers): ModuleList(
#     (0): ModuleList(
#       (0-19): 20 x IAFLayer(
#         (down_conv_b): Conv2d(192, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_a): Conv2d(160, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_b): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_conv_a): Conv2d(160, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_ar_conv): ARMultiConv2d(
#           (convs): ModuleList(
#             (0): MaskedConv2d(32, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): MaskedConv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (out_convs): ModuleList(
# ...

# %% [markdown]
# ### 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. Navigate to my repo

# %%
# !mkdir -p /content/drive/MyDrive/colab_projects
# %cd /content/drive/MyDrive/colab_projects
# Out:
# /content/drive/MyDrive/colab_projects

# %% [markdown]
# ### 3. Clone the repository

# %%
# !git clone https://github.com/alsugiliazova/iaf-vae.git
# Out:
# fatal: destination path 'iaf-vae' already exists and is not an empty directory.

# %%
# %cd iaf-vae
# Out:
# /content/drive/MyDrive/colab_projects/iaf-vae

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git checkout clean_original
# Out:
# Already on 'clean_original'
# Your branch is up to date with 'origin/clean_original'.

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### 4. Run Python script

# %%
# !python3 main.py --batch_size 512 --depth 1 --n_blocks 20 --free_bits 0.1 --lr 0.002 --z_size 32 --h_size 160 --iaf 1 --n_epochs 60
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# VAE(
#   (layers): ModuleList(
#     (0): ModuleList(
#       (0-19): 20 x IAFLayer(
#         (down_conv_b): Conv2d(192, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_a): Conv2d(160, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_b): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_conv_a): Conv2d(160, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_ar_conv): ARMultiConv2d(
#           (convs): ModuleList(
#             (0): ARConv2d(32, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ARConv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
# ...

# %%
# !python3 train_modular.py --decoder_type weak --decoder_subtype mlp --n_epochs 50 --data_dir ./data
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...
# Model Architecture:
# ...
# ModularVAE(
#   (encoder_layers): ModuleList(
#     (0): ModuleList(
#       (0-19): 20 x IAFLayer(
#         (down_conv_b): Conv2d(192, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_a): Conv2d(160, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_b): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_conv_a): Conv2d(160, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_ar_conv): ARMultiConv2d(
#           (convs): ModuleList(
#             (0): MaskedConv2d(32, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): MaskedConv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
# ...

# %%
# !python3 train_modular.py --decoder_type strong --n_epochs 50 --data_dir ./data
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...
# Model Architecture:
# ...
# ModularVAE(
#   (encoder_layers): ModuleList(
#     (0): ModuleList(
#       (0-19): 20 x IAFLayer(
#         (down_conv_b): Conv2d(192, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_a): Conv2d(160, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_b): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_conv_a): Conv2d(160, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_ar_conv): ARMultiConv2d(
#           (convs): ModuleList(
#             (0): MaskedConv2d(32, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): MaskedConv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
# ...

# %%
Train another weak

# %%
# !python3 train_modular.py --decoder_type weak --decoder_subtype mlp --n_epochs 60 --data_dir ./data --batch_size 256
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...
# Model Architecture:
# ...
# ModularVAE(
#   (encoder_layers): ModuleList(
#     (0): ModuleList(
#       (0-19): 20 x IAFLayer(
#         (down_conv_b): Conv2d(192, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_a): Conv2d(160, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (up_conv_b): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_conv_a): Conv2d(160, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (down_ar_conv): ARMultiConv2d(
#           (convs): ModuleList(
#             (0): MaskedConv2d(32, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): MaskedConv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
# ...
